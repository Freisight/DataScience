# %%
# Задание 1

# Для датафрейма log из материалов занятия создайте столбец source_type по следующим правилам:

# если источник traffic_source равен yandex или google, то в source_type ставится organic
# для источников paid и email из России - ставим ad
# для источников paid и email не из России - ставим other
# все остальные варианты берем из traffic_source без изменений

# %%
import pandas as pd
log = pd.read_csv('other/visit_log.csv', sep=';')

# %%
log.loc[(log['traffic_source'] == 'yandex') | (log['traffic_source'] == 'google'), 'source_type'] = 'organic'
# log.loc[log['traffic_source'] == 'google', 'source_type'] = 'organic'
log.loc[(log['region'] == 'Russia') & (log['traffic_source'] == 'paid'), 'source_type'] = 'ad'
log.loc[(log['region'] != 'Russia') & (log['traffic_source'] == 'paid'), 'source_type'] = 'other'
log.loc[(log['region'] == 'Russia') & (log['traffic_source'] == 'email'), 'source_type'] = 'ad'
log.loc[(log['region'] != 'Russia') & (log['traffic_source'] == 'email'), 'source_type'] = 'other'
log.head(10)

# а можно ли через функцию apply пропускать информацию из двух столбцов?
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
# 5  1549980742  8855508aad  https://host.ru/df646c3676cc259fa0  Russia
# 6  1549980742  b0f66adc83  https://host.ru/b8b58337d272ee7b15  Russia
# 7  1549980754  837885c8f8  https://host.ru/108ce4b365afb7b88e  Russia
# 8  1549980760  af5570f5a1  https://host.ru/3004a8273caeef2867   China
# 9  1549980765  3e7077fd2f  https://host.ru/df646c3676cc259fa0  Russia
#
#       user_id traffic_source source_type
# 0  b1613cc09f         yandex     organic
# 1  4c3ec14bee         direct         NaN
# 2  a8c40697fb         yandex     organic
# ...

# %%
# Задание 2

# В файле URLs.txt содержатся url страниц новостного сайта. Вам необходимо отфильтровать его по адресам страниц с текстами новостей. Известно, что шаблон страницы новостей имеет внутри url следующую конструкцию: /, затем 8 цифр, затем дефис. Выполните следующие действия:

# Прочитайте содержимое файла с датафрейм
# Отфильтруйте страницы с текстом новостей, используя метод str.contains и регулярное выражение в соответствии с заданным шаблоном

# %%
site = pd.read_csv('other/URLs.txt')

# %%
new_info = site[site['url'].str.contains('\\d{8}\-', na=False)]
new_info.head(20)
# Out:
#                                                   url
# 3   /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# 5   /science/36157853-nasa-sobiraet-ekstrennuyu-pr...
# 6   /video/36001498-poyavilis-pervye-podrobnosti-g...
# 7   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# 10  /middleeast/36131117-divizion-s-400-ne-zametil...
# 11  /economics/36065674-rossiyane-vozmutilis-minim...
# 12  /politics/36118047-otets-24-detey-potreboval-i...
# 13  /travel/36194479-v-sheremetevo-passazhiry-ustr...
# 14  /politics/35638742-nesolidno-mariya-zaharova-s...
# 15  /video/36012692-tramp-otkrestilsya-ot-rossii-i...
# 16     /starlife/36174817-guzeeva-rasstalas-s-muzhem/
# 17  /health/36149308-predlozheno-prostoe-sredstvo-...
# 18  /science/36139723-set-vzbudorazhila-novost-o-s...
# 19  /cis/36229699-poroshenko-obyavil-vseukrainskiy...
# 20  /incidents/36225203-tonnel-obrushilsya-v-novoy...
# ...

# %%
# Задание 3

# Используйте файл с оценками фильмов ml-latest-small/ratings.csv. Посчитайте среднее время жизни пользователей, которые выставили более 
# 100 оценок. Под временем жизни понимается разница между максимальным и минимальным значением столбца timestamp
# для данного значения userId.

# %%
rate = pd.read_csv('other/ml-latest-small/ratings.csv')

# таков путь:
# groupby userId
# rating count > 100
# livetime = timestamp max - timestamp min
# mean livetime (timestamp)

diff_time = rate.groupby('userId').agg({'timestamp': ['min', 'max']})
# сортировка по юзер айди, но выводим по каждому юзеру минимальное время и максимальное время через agg() который позволит
# вычислить дальше разницу

diff_time['dif'] = diff_time[('timestamp', 'max')] - diff_time[('timestamp', 'min')] #новый столбец с временем жизни
diff_time = diff_time.drop('timestamp', axis=1)  #удаляем лишнее
diff_time

# этот датафрейм показывает разницу lifetime теперь нам надо сделать джойн из первой таблицы и получить тех у кого 100 оценок и выше с 
# временнем lifetime потом мы уже делаем mean в окончательной таблице
# Out:
#              dif
#
# userId
# 1             97
# 2            851
# 3          71198
# 4         203560
# 5           2101
# ...          ...
# 667         1014
# 668          282
# 669          685
# 670      2162705
# 671     11283984
#
# [671 rows x 1 columns]

# %%
ratings_rate = g.rename(columns={'movieId' : 'rate'}).drop(['rating', 'timestamp'], axis=1)
top_users = ratings_rate[ratings_rate['rate'] >= 100]
top_user_livetime = top_users.join(diff_time, how="left") #соединяем таблицу оценок свыше 100 штук на юзера с таблицей времени жизни
top_user_livetime.rename(columns={"('dif', '')" : 'livetime'}) #не получается таргетироваться на кривое название
top_user_livetime[[('dif', '')]].mean()

# мне не понятен вот такой формат вывода, иначе среднее не получается вывести
# подскажите пожалуйста, как избавиться от мультиндекса - пробовал несколько вариантов - везде ошибки
# Out:
# /Users/freisturz/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py:648: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)
#           (dif, )
# userId
# 4          203560
# 5            2101
# 8           85187
# 15      471393496
# 17           8053
# ...           ...
# 656          3053
# 659      31609411
# 664      98180439
# 665      54131471
# 671      11283984
#
# [263 rows x 1 columns]

# %%
# Задание 4

# Дана статистика услуг перевозок клиентов компании по типам (см. файл “Python_13_join.ipynb” в разделе Материалы для лекции
# «Продвинутый pandas» ---- Ноутбуки к лекции «Продвинутый pandas»).

# Необходимо сформировать две таблицы:
# таблицу с тремя типами выручки для каждого client_id без указания адреса клиента
# аналогичную таблицу по типам выручки с указанием адреса клиента

# %%
rzd = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115],
        'rzd_revenue': [1093, 2810, 10283, 5774, 981]
    }
)
rzd = rzd.set_index('client_id')
rzd
# Out:
#            rzd_revenue
# client_id
# 111               1093
# 112               2810
# 113              10283
# 114               5774
# 115                981

# %%
auto = pd.DataFrame(
    {
        'client_id': [113, 114, 115, 116, 117],
        'auto_revenue': [57483, 83, 912, 4834, 98]
    }
)
auto
auto.set_index('client_id', inplace=True)
auto
# Out:
#            auto_revenue
# client_id
# 113               57483
# 114                  83
# 115                 912
# 116                4834
# 117                  98

# %%
air = pd.DataFrame(
    {
        'client_id': [115, 116, 117, 118],
        'air_revenue': [81, 4, 13, 173]
    }
)
air.set_index('client_id', inplace=True)
air
# Out:
#            air_revenue
# client_id
# 115                 81
# 116                  4
# 117                 13
# 118                173

# %%
client_base = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115, 116, 117, 118],
        'address': ['Комсомольская 4', 'Энтузиастов 8а', 'Левобережная 1а', 'Мира 14', 'ЗЖБИиДК 1', 
                    'Строителей 18', 'Панфиловская 33', 'Мастеркова 4']
    }
)
client_base.set_index('client_id', inplace=True)
client_base
# Out:
#                    address
# client_id
# 111        Комсомольская 4
# 112         Энтузиастов 8а
# 113        Левобережная 1а
# 114                Мира 14
# 115              ЗЖБИиДК 1
# 116          Строителей 18
# 117        Панфиловская 33
# 118           Мастеркова 4

# %%
# тут выводим таблицу всех клиентов без адресов
all = rzd.join(auto, how="outer").join(air, how="outer")
all.fillna('0').reset_index() #нули поменял для вида, для рассчетов нулди надо поменять обратно на NaN
# Out:
#    client_id rzd_revenue auto_revenue air_revenue
# 0        111      1093.0            0           0
# 1        112      2810.0            0           0
# 2        113     10283.0      57483.0           0
# 3        114      5774.0         83.0           0
# 4        115       981.0        912.0        81.0
# 5        116           0       4834.0         4.0
# 6        117           0         98.0        13.0
# 7        118           0            0       173.0

# %%
# тут выводим полную таблицу всех людей с адресами
all_base = client_base.join(rzd, how='outer').join(auto, how='outer').join(air, how='outer').reset_index()
all_base = all_base.fillna('0')
all_base
# Out:
#    client_id          address rzd_revenue auto_revenue air_revenue
# 0        111  Комсомольская 4      1093.0            0           0
# 1        112   Энтузиастов 8а      2810.0            0           0
# 2        113  Левобережная 1а     10283.0      57483.0           0
# 3        114          Мира 14      5774.0         83.0           0
# 4        115        ЗЖБИиДК 1       981.0        912.0        81.0
# 5        116    Строителей 18           0       4834.0         4.0
# 6        117  Панфиловская 33           0         98.0        13.0
# 7        118     Мастеркова 4           0            0       173.0
